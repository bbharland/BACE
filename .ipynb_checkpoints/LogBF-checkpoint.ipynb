# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# from BACETest import *

# %% [markdown]
# # IV.  Working through Bowman eq. 3 toward something looking like mine
#
# $$
# \log BF = N\sum_{i\in\alpha}\sum_jP_{ij}\log\frac{P_{ij}}{P_{\alpha j}} - N\sum_{i\in\alpha}p_i\log\frac{p_i}{p_\alpha}
# $$

# %%
from BACETest import *

m = BowmanModel()
C = m.C
state_list = m.state_list
nstates = C.shape[0]
micro = LogEvidenceMicrostates(C)
N = C.sum()

logBF_table = calc_logBF_table(C)
alpha = list(logBF_table[0, :2].astype(int))
alpha
# Out:
# [1, 2]

# %%
calc_logBF_Bowman_eq3(C, alpha)
# Out:
# 855.417321997546

# %%
divPQ_aa, divPQ_an, divpq = calc_logBF_Bowman_A(C, alpha)
print('N*divPQ_aa =', N*divPQ_aa)
print('N*divPQ_an =', N*divPQ_an)
print('N*divpq =', N*divpq)
print('logBF Bowman =', N * (divPQ_aa + divPQ_an - divpq))
print('logBF Bowman =', calc_logBF_Bowman_eq3(C, alpha))
# Out:
# N*divPQ_aa = -670.199414168324
# N*divPQ_an = -138.62943611198904
# N*divpq = -1664.2461722778585
# logBF Bowman = 855.4173219975456
# logBF Bowman = 855.417321997546

# %%
divPQ_aa, divPQ_an, divpq = calc_logBF_me(C, alpha)
print('N*divPQ_aa =', N*divPQ_aa)
print('N*divPQ_an =', N*divPQ_an)
print('N*divpq =', N*divpq)
print('logBF me =', N * (divPQ_aa + 2*divPQ_an - divpq))
# Out:
# N*divPQ_aa = -2195.1232114002037
# N*divPQ_an = -138.62943611198904
# N*divpq = -1664.2461722778585
# logBF me = -808.135911346323

# %% [markdown]
# # V.  Check `LogBF` code

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from BACETest import BowmanModel, calc_logBF_table
from LogBF import LogBF

m = BowmanModel()
C = m.C
bf = LogBF(C)
state_list = m.state_list
nstates = C.shape[0]
N = C.sum()

logBF_table = calc_logBF_table(C)
alpha = list(logBF_table[0, :2].astype(int))
alpha
# Out:
# [1, 2]

# %% [markdown]
# ## Compare logBF's

# %%
print('LogBF, Bowman, Eq. 3\t', bf.calc_logBF_Bowman_eq3(C, alpha))
print('LogBF, Bowman, PQ\t', bf.calc_logBF_Bowman_PQ(C, alpha))
print('LogBF, me, PQ\t\t', bf.calc_logBF_PQ(C, alpha))
# Out:
# LogBF, Bowman, Eq. 3	 855.417321997546
# LogBF, Bowman, PQ	 855.4173219975456
# LogBF, me, PQ		 -808.135911346323

# %% [markdown]
# ## Compare individual terms

# %%
pq, PQ_aa_Bowman, PQ_an = bf.calc_sum_PQ_terms(C, alpha, Bowman=True)
print(N*pq, '\tpq')
print(N*PQ_aa_Bowman, '\tPQ_aa (Bowman)')
print(N*PQ_an, '\tPQ_an')
print(N*(PQ_aa_Bowman + PQ_an - pq), '\tlogBF (Bowman)')
# Out:
# -1664.2461722778585 	pq
# -670.199414168324 	PQ_aa (Bowman)
# -138.62943611198904 	PQ_an
# 855.4173219975456 	logBF (Bowman)

# %%
pq, PQ_aa, PQ_an = bf.calc_sum_PQ_terms(C, alpha, Bowman=False)
print(N*pq, '\tpq')
print(N*PQ_aa, '\tPQ_aa (me)')
print(N*PQ_an, '\tPQ_an')
print(N*(PQ_aa + 2*PQ_an - pq), '\tlogBF (me)')
# Out:
# -1664.2461722778585 	pq
# -2195.1232114002037 	PQ_aa (me)
# -138.62943611198904 	PQ_an
# -808.135911346323 	logBF (me)

# %% [markdown]
# ## Take a close look at `PQ_aa`, me vs. Bowman
#
# ### Conclusion for $\alpha$ = [1, 2]
#
# ### Me
#
# $$
# N\sum_{i\in\alpha}\sum_{j\in\alpha} P_{ij}\log\frac{P_{ij}}{P_{\alpha\alpha}} = -2195.12
# $$
#
# 73 % of the $log BF_{\alpha\alpha}$ term is from $P_{11}, P_{22}$ terms
#
# 27 % of the $log BF_{\alpha\alpha}$ term is from $P_{12}, P_{21}$ terms
#
# ### Bowman
#
# $$
# N\sum_{i\in\alpha}\sum_{j\in\alpha} P_{ij}\log\frac{P_{ij}}{P_{\alpha j}} = -670.199
# $$
#
# 28 % of the $log BF_{\alpha\alpha}$ term is from $P_{11}, P_{22}$ terms
#
# 72 % of the $log BF_{\alpha\alpha}$ term is from $P_{12}, P_{21}$ terms

# %%
p_a, P_aa, P_an = bf._calc_p_P_blocks(C, alpha)

# %% [markdown]
# ### Check `bf._calc_p_P_blocks(C, alpha)` by hand -- ok

# %%
C
# Out:
# array([[1000,  100,  100,   10,    0,    0,    0,    0,    0],
#        [ 100, 1000,  100,    0,    0,    0,    0,    0,    0],
#        [ 100,  100, 1000,    0,    1,    0,    0,    0,    0],
#        [  10,    0,    0, 1000,  100,  100,   10,    0,    0],
#        [   0,    0,    1,  100, 1000,  100,    0,    0,    0],
#        [   0,    0,    0,  100,  100, 1000,    0,    1,    0],
#        [   0,    0,    0,   10,    0,    0, 1000,  100,  100],
#        [   0,    0,    0,    0,    0,    1,  100, 1000,  100],
#        [   0,    0,    0,    0,    0,    0,  100,  100, 1000]])

# %%
p_a, P_aa, P_an = bf._calc_p_P_blocks(C, [1, 4])

# %%
N*p_a
# Out:
# array([1200., 1201.])

# %%
C.sum(axis=1)
# Out:
# array([1210, 1200, 1201, 1220, 1201, 1201, 1210, 1201, 1200])

# %%
N*P_aa
# Out:
# array([[1000.,    0.],
#        [   0., 1000.]])

# %%
N*P_an
# Out:
# array([[100., 100.,   0.,   0.,   0.,   0.,   0.],
#        [  0.,   1., 100., 100.,   0.,   0.,   0.]])

# %% [markdown]
# ### Back to $\alpha$ = 1, 2

# %%
p_a, P_aa, P_an = bf._calc_p_P_blocks(C, alpha)

# %%
alpha
# Out:
# [1, 2]

# %%
N*P_aa
# Out:
# array([[1000.,  100.],
#        [ 100., 1000.]])

# %%
N*P_an
# Out:
# array([[100.,   0.,   0.,   0.,   0.,   0.,   0.],
#        [100.,   0.,   1.,   0.,   0.,   0.,   0.]])

# %% [markdown]
# ### Back to `PQ_aa` -- Bowman

# %%
N * P_aa
# Out:
# array([[1000.,  100.],
#        [ 100., 1000.]])

# %%
P_aa.sum()
# Out:
# 0.20287716709701217

# %%
P_aa.sum(axis=0) # Correct!
# Out:
# array([0.10143858, 0.10143858])

# %%
P_aa
# Out:
# array([[0.09221689, 0.00922169],
#        [0.00922169, 0.09221689]])

# %%
print('P_11 log P_11/P_a1\t', 0.09221689 * np.log(0.09221689 / 0.10143858))
print('P_12 log P_12/P_a2\t', 0.00922169 * np.log(0.00922169 / 0.10143858))
print('P_21 log P_21/P_a1\t', 0.00922169 * np.log(0.00922169 / 0.10143858))
print('P_22 log P_22/P_a2\t', 0.09221689 * np.log(0.09221689 / 0.10143858))
# Out:
# P_11 log P_11/P_a1	 -0.00878920927598656
# P_12 log P_12/P_a2	 -0.02211264594912105
# P_21 log P_21/P_a1	 -0.02211264594912105
# P_22 log P_22/P_a2	 -0.00878920927598656

# %%
P_aa * np.log(P_aa / P_aa.sum(axis=0))  # Correct!
# Out:
# array([[-0.00878921, -0.02211265],
#        [-0.02211265, -0.00878921]])

# %%
N*np.sum(P_aa * np.log(P_aa / P_aa.sum(axis=0)))
# Out:
# -670.199414168324

# %%
_, sumPQ_aa, _ = bf.calc_sum_PQ_terms(C, alpha, Bowman=True) # Correct!
N*sumPQ_aa
# Out:
# -670.199414168324

# %%
0.00878921 / (0.02211265 + 0.00878921)
# Out:
# 0.2844233324466553

# %% [markdown]
# ### Close look at my `PQ_aa`

# %%
P_aa
# Out:
# array([[0.09221689, 0.00922169],
#        [0.00922169, 0.09221689]])

# %%
P_aa.sum()
# Out:
# 0.20287716709701217

# %%
P_aa * np.log(P_aa / P_aa.sum()) # Correct
# Out:
# array([[-0.07270909, -0.02850463],
#        [-0.02850463, -0.07270909]])

# %%
print('P_11 log P_11/P_aa\t', 0.09221689 * np.log(0.09221689 / 0.20287716709701217))
print('P_12 log P_12/P_aa\t', 0.00922169 * np.log(0.00922169 / 0.20287716709701217))
print('P_21 log P_21/P_aa\t', 0.00922169 * np.log(0.00922169 / 0.20287716709701217))
print('P_22 log P_22/P_aa\t', 0.09221689 * np.log(0.09221689 / 0.20287716709701217))
# Out:
# P_11 log P_11/P_aa	 -0.0727090898054077
# P_12 log P_12/P_aa	 -0.02850463469521038
# P_21 log P_21/P_aa	 -0.02850463469521038
# P_22 log P_22/P_aa	 -0.0727090898054077

# %%
-(0.0727090898054077 + 0.02850463469521038 + 0.02850463469521038 + 0.0727090898054077)
# Out:
# -0.20242744900123616

# %%
np.sum(P_aa * np.log(P_aa / P_aa.sum())) # Correct!
# Out:
# -0.20242744479898594

# %%
_, sumPQ_aa, _ = bf.calc_sum_PQ_terms(C, alpha, Bowman=False) # Correct!
N*sumPQ_aa
# Out:
# -2195.1232114002037

# %%
N * np.sum(P_aa * np.log(P_aa / P_aa.sum())) # Correct!
# Out:
# -2195.1232114002037

# %%
print('sum PQ_aa - me\t', )

# %% [markdown]
# ## Take a close look at `PQ_an` = 0 terms
#
# ### Conclusion for $\alpha$ = [2, 4]
#
# $\log BF_{\alpha\alpha'} = 0$ since either:
# * case: $P_{ij} = P_{\alpha j} \ne 0 \rightarrow \log 1 = 0$
# * case: $P_{ij} = 0, P_{\alpha j} \ne 0 \rightarrow \log 0 = nan \rightarrow 0$
# * case: $P_{ij} = P_{\alpha j} = 0 \rightarrow \log nan = nan \rightarrow 0$

# %%
p_a, P_aa, P_an = bf._calc_p_P_blocks(C, [2, 4])
P_an
# Out:
# array([[0.00922169, 0.00922169, 0.        , 0.        , 0.        ,
#         0.        , 0.        ],
#        [0.        , 0.        , 0.00922169, 0.00922169, 0.        ,
#         0.        , 0.        ]])

# %%
Q_an = P_an.sum(axis=0)
Q_an
# Out:
# array([0.00922169, 0.00922169, 0.00922169, 0.00922169, 0.        ,
#        0.        , 0.        ])

# %%
P_an / Q_an
# Out:
# /home/bharland/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# array([[ 1.,  1.,  0.,  0., nan, nan, nan],
#        [ 0.,  0.,  1.,  1., nan, nan, nan]])

# %%
with np.errstate(divide='ignore', invalid='ignore'):
    PlogP = P_an * np.log(P_an / Q_an)
    PlogP[np.isneginf(PlogP) | np.isnan(PlogP)] = 0        
sumPQ_an = PlogP.sum()
sumPQ_an
# Out:
# 0.0

# %% [markdown]
# ## Test $\log BF_\theta$ -- Microstates
#
# ### `bf.calc_logBF_microstates(state_list, [1, 2])`
#
# $$
# \log BF_\theta = \log\frac{different}{same} = \log P(C|BL) - \log P(C|B_\alpha L_\alpha)
# $$
#
# $$
# \log P(C|BL) = -\sum_{M\in L} \hat{B}_M\mathcal{H}(\Theta_M)
# $$
#
# $$
# \mathcal{H}(\Theta_M) = -\sum_{m\in M}\theta_m\log\theta_m
# $$
#
# $$
# \theta_m = \frac{\hat{C}_m}{\hat{B}_M} ~~~~~~~ \hat{B}_M = \sum_{m\in M}\hat{C}_m
# $$
#
# * Starting from full microstate model, where $\log P(C|CL) = 0$, the $\log BF_\theta$ will be positive
#
# * This is because
# $$
# \log BF_\theta = -\log P(C|B_\alpha L_\alpha)
# $$
# and
# $$
# -\log P(C|B_\alpha L_\alpha) = +\hat{B}_\alpha\mathcal{H}(\Theta_\alpha) = -\hat{B}_\alpha\sum_{m\in\alpha}\theta_m\log\theta_m
# $$

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from BowmanModel import BowmanModel
from ThreeMacrostateModel import ThreeMacrostateModel
from LogBF import LogBF

# %precision 4
np.set_printoptions(suppress=True)

m = BowmanModel()
C = m.C
state_list = m.state_list
bf = LogBF(C)

# %%
state_list
# Out:
# [[0], [1], [2], [3], [4], [5], [6], [7], [8]]

# %%
bf.calc_logBF_evidence_microstates(state_list, [1, 2])
# Out:
# 1664.2461722778587

# %%
bf.calc_log_evidence_microstates(state_list)
# Out:
# 0.0

# %%
bf.calc_log_evidence_microstates(calc_state_list_merged(state_list, [1, 2]))
# Out:
# -1664.2461722778587

# %%
C.sum(axis=1)
# Out:
# array([1210, 1200, 1201, 1220, 1201, 1201, 1210, 1201, 1200])

# %%
1200 / 2401
# Out:
# 0.4998

# %%
0.4997917534360683 * np.log(0.4997917534360683)
# Out:
# -0.34663744795260054

# %%
1201 / 2401
# Out:
# 0.5002

# %%
0.5002082465639317 * np.log(0.5002082465639317)
# Out:
# -0.3465096458740795

# %%
B_alpha = 1200 + 1201
H_theta = -(-0.34663744795260054 + -0.3465096458740795)
evidence_alpha = -B_alpha * H_theta
log_BF_12 = 0 - evidence_alpha
log_BF_12
# Out:
# 1664.2462

# %%
bf.calc_logBF_evidence_microstates(state_list, [1, 2])
# Out:
# 1664.2461722778587

# %%
bf.calc_logBF_microstates(state_list, [1, 2])
# Out:
# 1664.246172277859

# %% [markdown]
# # VI. Make plots of terms in $\log BF$
#
# <img src="figures/logBF-terms.png" style="width: 400px;">

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from LogBF import LogBF

def calc_logBF_terms(C):
    bf = LogBF(C)
    logBF_table = calc_logBF_table(C)
    alpha_list = [list(logBF_table[i, :2].astype(int)) for i in range(len(logBF_table))]
    N = C.sum()
    
    logBF_Bowman = []
    logBF = []
    for alpha in alpha_list:
        logBF_Bowman.append(list(bf.calc_sum_PQ_terms(C, alpha, Bowman=True)))
        logBF.append(list(bf.calc_sum_PQ_terms(C, alpha, Bowman=False)))

    labels = [','.join([str(i) for i in alpha]) for alpha in alpha_list]
    return labels, N * np.array(logBF_Bowman), N * np.array(logBF)

def calc_logBF_table(C):
    bf = LogBF(C)
    logBF_table = []
    for i in range(C.shape[0]):
        for j in range(i+1, C.shape[1]):
            if C[i, j] > 0:
                logBF = bf.calc_logBF_Bowman_eq3(C, [i, j])
                logBF_table.append([i, j, logBF])
    logBF_table = np.array(logBF_table)
    return logBF_table[logBF_table[:,2].argsort()]

def plot_logBF_terms(ax, logBF_Bowman, logBF, labels):
    alpha = 1.0
    width = 0.35
    pos = np.array(range(len(labels)))
    pos_m = pos - width/2
    pos_p = pos + width/2

    ax.set_xlabel(r'$\alpha$')
    ax.set_xticks(pos)
    ax.set_xticklabels(labels, rotation=45)

    ax.bar(pos, -logBF[:, 0], width=width*2, 
           label=r"$\alpha$", alpha=0.6, color='gray')

    ax.bar(pos_m, logBF_Bowman[:, 1], width=width, 
           label=r"$\alpha\alpha$, Bowman", 
           alpha=alpha, color='orange')

    ax.bar(pos_m, logBF_Bowman[:, 2], width=width, bottom=logBF_Bowman[:, 1], 
           label=r"$\alpha\alpha'$, Bowman", 
           alpha=alpha, color='khaki')

    ax.bar(pos_p, logBF[:, 1], width=width, 
           label=r'$\alpha\alpha$, Proposed', 
           alpha=alpha, color='steelblue')

    ax.bar(pos_p, 2*logBF[:, 2], width=width, bottom=logBF[:, 1], 
           label=r"$\alpha\alpha'+\alpha'\alpha$, Proposed", 
           alpha=alpha, color='lightsteelblue')

    total = logBF_Bowman[:, 1] + logBF_Bowman[:, 2] - logBF_Bowman[:, 0]
    ax.plot(total, linewidth=2.5, color='darkorange', label=r'$\log BF$, Bowman')
    total = logBF[:, 1] + 2*logBF[:, 2] - logBF[:, 0]
    ax.plot(total, linewidth=2.5, color='darkslateblue', label=r'$\log BF$, Proposed')

    ax.legend(loc='lower right', bbox_to_anchor=(1.4, 0))
    
def draw_graph_cbf(model, ax):
    import networkx as nx
    import matplotlib
    
    labels, G = model._build_graph(model.C)
    edge_factor = 0.1
    weights = [G[i][j]['weight'] * edge_factor for i, j in G.edges()]
    label_list = list(labels)
    bfvals = []
    for ilabel, jlabel in G.edges:
        i = label_list.index(ilabel)
        j = label_list.index(jlabel)
        bfvals.append(model.log_BF_matrix[i, j])

    pos = nx.spring_layout(G, iterations=300)
    _ = nx.draw_networkx_nodes(G, pos, node_color='lightblue',
                               node_size=1000, alpha=1, ax=ax)
    _ = nx.draw_networkx_labels(G, pos, labels,
                                font_size=12, alpha=1, ax=ax)
    edges = nx.draw_networkx_edges(G, pos, edgelist=G.edges, 
                                   alpha=0.8, width=weights, 
                                   edge_color=bfvals, 
                                   edge_cmap=plt.cm.viridis, ax=ax)
    ax.axis('off')

# %%
from BowmanModel import BowmanModel
from ThreeMacrostateModel import ThreeMacrostateModel

gridsize = (2, 10)
fig = plt.figure(figsize=(18, 8))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=5, rowspan=1)
ax2 = plt.subplot2grid(gridsize, (1, 0), colspan=5, rowspan=1)
ax3 = plt.subplot2grid(gridsize, (0, 7), colspan=2, rowspan=1)
ax4 = plt.subplot2grid(gridsize, (1, 7), colspan=2, rowspan=1)

m = BowmanModel()
m.calc_log_BF_matrix()
C = m.C
labels, logBF_Bowman, logBF = calc_logBF_terms(C)

plot_logBF_terms(ax1, logBF_Bowman, logBF, labels)
draw_graph_cbf(m, ax3)

m3 = ThreeMacrostateModel()
m3.calc_log_BF_matrix()
C = m3.C
labels, logBF_Bowman, logBF = calc_logBF_terms(C)
plot_logBF_terms(ax2, logBF_Bowman, logBF, labels)
draw_graph_cbf(m3, ax4)

plt.savefig('figures/logBF-terms.png', dpi=200)

# %% [markdown]
# # VII. Plots:  Terms in $\log BF$ while clustering
#
# <table>
#     <td> <img src='figures/logBF-terms-Bowman-clustering-good.png' style="width: 200px;"> </td>
#     <td> <img src='figures/logBF-terms-threestate-clustering.png' style="width: 200px;"> </td>
# <table>

# %% [markdown]
# ### `calc_alpha_list`
# ### `calc_logBF_terms`, `plot_logBF_terms`

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from LogBF import LogBF
from LogBF import calc_C_merged, calc_state_list_merged
from LogBF import get_alpha_label

def calc_alpha_list(logBF_table):
    return [list(logBF_table[i, :2].astype(int)) for i in range(len(logBF_table))]

def calc_logBF_terms(model, bf):
    logBF_table = bf.calc_logBF_table(model.C, model.state_list, Gmethod=2)
    alpha_list = calc_alpha_list(logBF_table)
    N = model.C.sum()
    
    logBF_Bowman = []
    logBF = []
    for alpha in alpha_list:
        logBF_Bowman.append(list(bf.calc_sum_PQ_terms(model.C, alpha, Bowman=True)))
        logBF.append(list(bf.calc_sum_PQ_terms(model.C, alpha, Bowman=False)))

    labels = [get_alpha_label(model.state_list, alpha) for alpha in alpha_list]
    logBF_Bowman = N * np.array(logBF_Bowman)
    logBF = N * np.array(logBF)
    return alpha_list[0], labels, logBF_Bowman, logBF

def plot_logBF_terms(ax, logBF_Bowman, logBF, labels, legend=False):
    alpha = 1.0
    width = 0.35
    pos = np.array(range(len(labels)))
    pos_m = pos - width/2
    pos_p = pos + width/2

    ax.set_xlabel(r'$\alpha$')
    ax.set_xticks(pos)
    ax.set_xticklabels(labels, rotation=45)
    
    ax.set_ylim(-5000, 5000)
    ax.set_yticks([-4000, -2000, 0, 2000, 4000])

    ax.bar(pos, -logBF[:, 0], width=width*2, 
           label=r"$\alpha$", alpha=0.6, color='gray')

    ax.bar(pos_m, logBF_Bowman[:, 1], width=width, 
           label=r"$\alpha\alpha$, Bowman", 
           alpha=alpha, color='orange')

    ax.bar(pos_m, logBF_Bowman[:, 2], width=width, bottom=logBF_Bowman[:, 1], 
           label=r"$\alpha\alpha'$, Bowman", 
           alpha=alpha, color='khaki')

    ax.bar(pos_p, logBF[:, 1], width=width, 
           label=r'$\alpha\alpha$, Proposed', 
           alpha=alpha, color='steelblue')

    ax.bar(pos_p, 2*logBF[:, 2], width=width, bottom=logBF[:, 1], 
           label=r"$\alpha\alpha'+\alpha'\alpha$, Proposed", 
           alpha=alpha, color='lightsteelblue')

    total = logBF_Bowman[:, 1] + logBF_Bowman[:, 2] - logBF_Bowman[:, 0]
    ax.plot(total, linewidth=2.5, color='darkorange', label=r'$\log BF$, Bowman')
    total = logBF[:, 1] + 2*logBF[:, 2] - logBF[:, 0]
    ax.plot(total, linewidth=2.5, color='darkslateblue', label=r'$\log BF$, Proposed')

    if legend:
#         anchor_loc = (1.4, 0)
        anchor_loc = (1.3, 0)
        ax.legend(loc='lower right', bbox_to_anchor=anchor_loc)

# %% [markdown]
# ### Clustering `BowmanModel`

# %%
from BowmanModel import BowmanModel
m = BowmanModel()
bf = LogBF(m.C)

rows = 6   # number of plots
cols = 4
scale = 2.2

fig = plt.figure(figsize=(8*scale, 2*rows*scale))
grid = plt.GridSpec(rows, cols, hspace=0.2, wspace=0.2)

for i in range(rows):
    ax = [fig.add_subplot(grid[i, 0]), fig.add_subplot(grid[i, 1:3])]
    alpha, labels, logBF_Bowman, logBF = calc_logBF_terms(m, bf)
    m.draw_graph_counts_ax(ax[0])
    if i == 0: legend=True
    else:      legend=False
    plot_logBF_terms(ax[1], logBF_Bowman, logBF, labels, legend=legend)
    m.merge_states(alpha)
    
# plt.savefig('figures/logBF-terms-Bowman-clustering.png', dpi=200)
# Out:
# /home/bharland/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# ### Clustering `ThreeMacrostateModel`

# %%
from ThreeMacrostateModel import ThreeMacrostateModel
m = ThreeMacrostateModel()
bf = LogBF(m.C)

rows = 9   # number of plots
cols = 4
scale = 2.2

fig = plt.figure(figsize=(8*scale, 2*rows*scale))
grid = plt.GridSpec(rows, cols, hspace=0.2, wspace=0.2)

for i in range(rows):
    ax = [fig.add_subplot(grid[i, 0]), fig.add_subplot(grid[i, 1:3])]
    alpha, labels, logBF_Bowman, logBF = calc_logBF_terms(m, bf)
    m.draw_graph_counts_ax(ax[0])
    if i == 0: legend=True
    else:      legend=False
    plot_logBF_terms(ax[1], logBF_Bowman, logBF, labels, legend=legend)
    m.merge_states(alpha)
    
# plt.savefig('figures/logBF-terms-threestate-clustering.png', dpi=200)
# Out:
# /home/bharland/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# # VIII.  Plots: compare $\log BF$'s during clustering
#
# 1.  Compare $\Delta G$:  Bowman vs. me
#
#
# 2.  Compare $\Delta F$:  Bowman vs. me vs. me+prior
#
#
# 3.  Add in microstates

# %% [markdown]
# ## `calc_logBF_table_microstates`
# ## `sort_table`

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from BowmanModel import BowmanModel
from ThreeMacrostateModel import ThreeMacrostateModel
from LogBF import LogBF, calc_C_merged, calc_state_list_merged

def calc_logBF_table_microstates(C, bf, state_list):
    from itertools import combinations
    logBF_table = []
    for i, j in combinations(range(C.shape[0]), 2):
        if C[i, j] > 0:
            logbf = bf.calc_logBF_microstates(state_list, [i, j])
            logBF_table.append([i, j, logbf])
    return np.array(logBF_table)

def sort_table(template_table, input_table):
    sorted_table = []
    for row in template_table:
        i, j = int(row[0]), int(row[1])
        index = find_table_index(input_table, [i, j])
        sorted_table.append(input_table[index, :])
    return np.array(sorted_table)

def find_table_value(table, alpha):
    for row in table:
        i, j = int(row[0]), int(row[1])
        if [i, j] == alpha or [j, i] == alpha:
            return row[2]
        
def find_table_index(table, alpha):
    for index, row in enumerate(table):
        i, j = int(row[0]), int(row[1])
        if [i, j] == alpha or [j, i] == alpha:
            return index

# %% [markdown]
# ## 1. Compare $\Delta G$, macrostates

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from LogBF import LogBF
from LogBF import calc_logBF_table_microstates
from LogBF import sort_table, find_table_value

# %precision 4
np.set_printoptions(suppress=True)

def plot_logBF_clustering(ax, m, n_stop, merge_by_Bowman=True):
    bf = LogBF(m.C)
    bf_macroB = []         # min logBF, Bowman
    bf_macro = []          # min logBF, me
    bf_micro = []          # min logBF, microstates
    bf_macroB_prs = []     # all pairs, Bowman
    bf_macro_prs = []      # all pairs, me
    bf_micro_prs = []      # all pairs, microstates
    n_start = m.C.shape[0]

    #=====================================
    #  Calculations
    #=====================================
    n = n_start
    while n >= n_stop:
        # Calculate logBF's
        table_macroB = bf.calc_logBF_table(m.C, m.state_list, Gmethod=2)
        table_macro = bf.calc_logBF_table(m.C, m.state_list, Gmethod=3)
        table_micro = bf.calc_logBF_table(m.C, m.state_list, Gmethod=4)

        # Merge best pair of states (using Bowman or my logBF)
        if merge_by_Bowman:
            alpha = list(table_macroB[0, :2].astype(int))
        else:
            alpha = list(table_macro[0, :2].astype(int))
        m.merge_states(alpha)
        n = m.C.shape[0]

        # Append data
        bf_macroB.append(table_macroB[0, 2])
        bf_macro.append(find_table_value(table_macro, alpha))
        bf_macroB_prs.append(table_macroB[:, 2])
        bf_macro_prs.append(table_macro[:, 2])
        
    # convert results to log10
    bf_macroB = np.log10(np.e) * np.array(bf_macroB)
    bf_macro = np.log10(np.e) * np.array(bf_macro)
    bf_macroB_prs = np.log10(np.e) * np.array(bf_macroB_prs)
    bf_macro_prs = np.log10(np.e) * np.array(bf_macro_prs)
    bf_macroB = np.log10(np.e) * np.array(bf_macroB)

    #=====================================
    #  Plot
    #=====================================
    offset = 0
    alpha_circles = 1.0
    alpha_line = 0.4
    ax.set_xlim(n_start + 1, n_stop - 1)

    # lines for min(logBF)
    ax.plot(range(n_start, n_finish - 1, -1), bf_macroB, 
            linewidth=4, color='darkorange', alpha=alpha_line)
    ax.plot(range(n_start, n_finish - 1, -1), bf_macro, 
            linewidth=4, color='darkslateblue', alpha=alpha_line)

    # circles for logBF points
    for n in range(n_start, n_finish - 1, -1):
        ax.plot(np.ones(len(bf_macroB_prs[n_start - n])) * n + offset, 
                 bf_macroB_prs[n_start - n], 
                 'o', markersize=10, fillstyle='none', 
                 color='darkorange',
                 alpha=alpha_circles)
        ax.plot(np.ones(len(bf_macro_prs[n_start - n])) * n - offset, 
                 bf_macro_prs[n_start - n], 
                 'o', markersize=10, fillstyle='none', 
                 color='darkslateblue',
                 alpha=alpha_circles)

# %% [markdown]
# ### making some plots

# %%
from BowmanModel import BowmanModel
m = BowmanModel()
fig, ax = plt.subplots(figsize=(8, 6))
plot_logBF_clustering(ax, m, 3)

# %%
m = BowmanModel()
fig, ax = plt.subplots(figsize=(8, 6))
plot_logBF_clustering(ax, m, 3, merge_by_Bowman=False)

# %%
from ThreeMacrostateModel import ThreeMacrostateModel
m = ThreeMacrostateModel()
fig, ax = plt.subplots(figsize=(8, 6))
plot_logBF_clustering(ax, m, 3)

# %%
m = ThreeMacrostateModel()
fig, ax = plt.subplots(figsize=(8, 6))
plot_logBF_clustering(ax, m, 3, merge_by_Bowman=False)

# %%
from BowmanModel import BowmanModel
from ThreeMacrostateModel import ThreeMacrostateModel

m = BowmanModel
bf = LogBF(m.C)

rows = 6   # number of plots
cols = 4
scale = 2.2

fig = plt.figure(figsize=(8*scale, 2*rows*scale))
grid = plt.GridSpec(rows, cols, hspace=0.2, wspace=0.2)

for i in range(rows):
    ax = [fig.add_subplot(grid[i, 0]), fig.add_subplot(grid[i, 1:3])]
    alpha, labels, logBF_Bowman, logBF = calc_logBF_terms(m, bf)
    m.draw_graph_counts_ax(ax[0])
    if i == 0: legend=True
    else:      legend=False
    plot_logBF_terms(ax[1], logBF_Bowman, logBF, labels, legend=legend)
    m.merge_states(alpha)

# %% [markdown]
# ## 2. Add in $\Delta F$

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from LogBF import LogBF
bf = LogBF(np.ones((10, 10)))

# %%
n = np.arange(100, 3, -1)
F = []
dF = []
for nval in n:
    F.append(bf._calc_F_Bowman(nval))
    dF.append(bf.calc_delta_F_Bowman(nval))

plt.ylim(-1000, 0)
plt.plot(n, F, '.-')
plt.plot(n, dF, '.')

# %% [markdown]
# ## 3. Add in microstates

# %% [markdown]
# # Take more accurate Stirling's approximation for $\log P(C|L)$
#
# $$
# \log P(C|L) \approx \underbrace{-n^2\log n}_\mathcal{A}
# + \underbrace{\frac{n(n-1)}{2}\log(2\pi)}_\mathcal{B}
# + \frac{1}{2}\left\{ \underbrace{\sum_i\sum_j\log C_{ij}}_\mathcal{C}
# - \underbrace{\sum_i\log C_i}_\mathcal{D} \right\}
# + \underbrace{\sum_i\sum_j C_{ij}\log\frac{C_{ij}}{C_i}}_\mathcal{E}
# $$
#
# ![image.png](attachment:image.png)

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from LogBF import LogBF
from BowmanModel import BowmanModel

def calc_A(C):
    n = C.shape[0]
    return -n**2 * np.log(n)

def calc_B(C):
    n = C.shape[0]
    return 0.5 * n * (n - 1) * np.log(2*np.pi)

def calc_C(C):
    with np.errstate(divide='ignore', invalid='ignore'):
        logC = np.log(C)
        logC[np.isneginf(logC) | np.isnan(logC)] = 0
    return np.sum(logC)

def calc_D(C):
    return np.sum(np.log(C.sum(axis=1)))

def calc_E(C):
    C = m.C
    Ci = C.sum(axis=1)
    p = C / Ci.reshape(C.shape[0], 1)
    with np.errstate(divide='ignore', invalid='ignore'):
        Clogp = C * np.log(p)
        Clogp[np.isneginf(Clogp) | np.isnan(Clogp)] = 0
    return Clogp.sum()

def calc_log_evidence_parts(C):
    results = {}
    results['A'] = calc_A(C)
    results['B'] = calc_B(C)
    results['C'] = 0.5 * calc_C(C)
    results['D'] = -0.5 * calc_D(C)
    results['E'] = calc_E(C)
    results['New'] = sum(results.values())   # High order Stirlings
    results['Old'] = results['A'] + results['E']  # Lower order
    return results

def compare_results(results, results2):
    for key in ('A', 'B', 'C', 'D', 'E', 'New', 'Old'):
        print(key, ': before', results[key])    
        print('    after ', results2[key])
        print('    change', results2[key] - results[key], '\n')

# %%
m = BowmanModel()
results = calc_log_evidence_parts(m.C)
results['New'], results['Old']
# Out:
# (-6444.435066159901, -6555.811665978547)

# %%
m.merge_states([0, 1])
results2 = calc_log_evidence_parts(m.C)
results2['New'], results2['Old']
# Out:
# (-5620.705332099022, -5709.002608459609)

# %%
compare_results(results, results2)
# Out:
# A : before -177.9751907642338
#     after  -133.0842586675095
#     change 44.8909320967243
#
# B : before 66.16357439073643
#     after  51.46055785946167
#     change -14.703016531274756
#
# C : before 77.13660061530054
#     after  65.55975846457537
#     change -11.57684215072517
#
# D : before -31.923575187390497
#     after  -28.72303996344941
#     change 3.2005352239410882
#
# E : before -6377.836475214313
#     after  -5575.918349792099
#     change 801.918125422214
#
# New : before -6444.435066159901
#     after  -5620.705332099022
#     change 823.7297340608793
#
# Old : before -6555.811665978547
#     after  -5709.002608459609
#     change 846.8090575189381

# %%
# Check that 'Old' change (negative) is in table
#   - Old = -846.80905752
#   [   0.        ,    1.        , -846.80905752]

from LogBF import LogBF
m = BowmanModel()
bf = LogBF(m.C)
bf.calc_logBF_table(m.C, m.state_list, Fmethod=2, Gmethod=3)
# Out:
# array([[   1.        ,    2.        , -853.02684344],
#        [   7.        ,    8.        , -853.02684344],
#        [   4.        ,    5.        , -852.33348802],
#        [   0.        ,    1.        , -846.80905752],
#        [   6.        ,    8.        , -846.80905752],
#        [   0.        ,    2.        , -846.11196144],
#        [   6.        ,    7.        , -846.11196144],
#        [   3.        ,    4.        , -839.23824832],
#        [   3.        ,    5.        , -839.23824832],
#        [   0.        ,    3.        ,  127.0757637 ],
#        [   3.        ,    6.        ,  127.0757637 ],
#        [   2.        ,    4.        ,  216.5514299 ],
#        [   5.        ,    7.        ,  216.5514299 ]])

# %% [markdown]
# ## `LogBFExtendedStirling`

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from LogBF import LogBF
from BowmanModel import BowmanModel

from itertools import combinations
class LogBFExtendedStirling(LogBF):
    """
    Extend the accuracy of Stirling's approximation.
    
    Usual LogBF uses :   n! ~ (n/e)**n
    Here, we extend to : n! ~ sqrt(2 pi n) * (n/e)**n
    
    Since LogBF separates the evidence into F, G terms, 
    we want to just add in corrections to those functions
    
    The log(BF) terms must be computed using 
    'calc_logBF_evidence_macrostates' ONLY!
    
    self._calc_F(n)
    self.calc_delta_F(n)
    self.calc_delta_F_prior(n)
    self.calc_logBF_evidence_macrostates(C, [i, j])
    
    """
    def calc_logBF_table(self, C, state_list, Fmethod=2, Gmethod=1):
        """
        Parameters : 
           Fmethod = 2       deltaF, no prior
                     3       deltaF, with prior

           Gmethod = 1       macrostates, using delta evidence

        Return : sorted table with rows = [i, j, logBF]
        """
        n = C.shape[0]
        if Fmethod is 2:
            dF = self.calc_delta_F(n)
        elif Fmethod is 3:
            dF = self.calc_delta_F_prior(n)
        else:
            raise RuntimeError('Fmethod must be 2 or 3')

        logBF_table = []
        for i, j in combinations(range(n), 2):
            if C[i, j] > 0:
                if Gmethod is 1:
                    dG = self.calc_logBF_evidence_macrostates(C, [i, j])
                else:
                    raise RuntimeError('Gmethod must be 1')
                    
                logBF_table.append([i, j, dF + dG])

        logBF_table = np.array(logBF_table)
        return logBF_table[logBF_table[:,2].argsort()]
    
    def calc_log_evidence_macrostates(self, C):
        le = super().calc_log_evidence_macrostates(C)
            
        # correction: 1/2 sum_ij log(C_ij)
        with np.errstate(divide='ignore', invalid='ignore'):
            logC = np.log(C)
            logC[np.isneginf(logC) | np.isnan(logC)] = 0
        le += 0.5 * np.sum(logC)
        
        # correction: -1/2 sum_i log(C_i)
        le -= 0.5 * np.sum(np.log(self.Ci))
        return le
    
    def _calc_F_correction(self, n):
        return 0.5*n*(n - 1) * np.log(2*np.pi)

    def _calc_F(self, n):
        return super()._calc_F(n) + self._calc_F_correction(n)
    
    def _calc_F_prior(self, n):
        return super()._calc_F_prior(n) + self._calc_F_correction(n)

# %%
m = BowmanModel()
bf = LogBF(m.C)
bfx = LogBFExtendedStirling(m.C)

bf.calc_log_evidence_macrostates(m.C), \
bfx.calc_log_evidence_macrostates(m.C)
# Out:
# (-6377.836475214313, -6332.623449786403)

# %% [markdown]
# ### Checking out evidence terms

# %%
n = m.C.shape[0]
bf._calc_F(n), bfx._calc_F(n)
# Out:
# (-177.9751907642338, -111.81161637349736)

# %%
bf._calc_F_prior(n), bfx._calc_F_prior(n)
# Out:
# (23648.72812586973, 23714.891700260465)

# %%
bf.calc_delta_F(n), bfx.calc_delta_F(n)
# Out:
# (-44.8909320967243, -30.187915565449543)

# %%
bf.calc_logBF_evidence_macrostates(m.C, [0, 1]), \
bfx.calc_logBF_evidence_macrostates(m.C, [0, 1])
# Out:
# (-801.918125422214, -790.3412832714894)

# %% [markdown]
# ### Checking $\log BF$ tables

# %%
bftab = bf.calc_logBF_table(m.C, m.state_list, Fmethod=2, Gmethod=1)
bftab
# Out:
# array([[   1.        ,    2.        , -853.02684344],
#        [   7.        ,    8.        , -853.02684344],
#        [   4.        ,    5.        , -852.33348802],
#        [   0.        ,    1.        , -846.80905752],
#        [   6.        ,    8.        , -846.80905752],
#        [   0.        ,    2.        , -846.11196144],
#        [   6.        ,    7.        , -846.11196144],
#        [   3.        ,    4.        , -839.23824832],
#        [   3.        ,    5.        , -839.23824832],
#        [   0.        ,    3.        ,  127.0757637 ],
#        [   3.        ,    6.        ,  127.0757637 ],
#        [   2.        ,    4.        ,  216.5514299 ],
#        [   5.        ,    7.        ,  216.5514299 ]])

# %%
bfxtab = bfx.calc_logBF_table(m.C, m.state_list, Fmethod=2, Gmethod=1)
bfxtab
# Out:
# array([[   1.        ,    2.        , -826.74698476],
#        [   7.        ,    8.        , -826.74698476],
#        [   4.        ,    5.        , -826.05362933],
#        [   0.        ,    1.        , -820.52919884],
#        [   6.        ,    8.        , -820.52919884],
#        [   0.        ,    2.        , -819.83210276],
#        [   6.        ,    7.        , -819.83210276],
#        [   3.        ,    4.        , -812.95838964],
#        [   3.        ,    5.        , -812.95838964],
#        [   0.        ,    3.        ,  147.18369421],
#        [   3.        ,    6.        ,  147.18369421],
#        [   2.        ,    4.        ,  234.36125073],
#        [   5.        ,    7.        ,  234.36125073]])

# %%
x = range(bftab.shape[0])
plt.plot(x, bftab[:, 2], label=r'$\log BF$')
plt.plot(x, bfxtab[:, 2], label=r'$\log BF$, Extended Stirling')
plt.legend()
